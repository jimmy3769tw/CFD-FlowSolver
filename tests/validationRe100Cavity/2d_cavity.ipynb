# %%
import matplotlib.pyplot as plt

# 读取数据文件
filename = '../../build/Information/y_plot_re_100.dat'

# 数据点
x = [1.0000, 0.9766, 0.9688, 0.9609, 0.9531, 0.8516, 0.7344, 0.6172, 0.5000, 0.4531, 0.2813, 0.1719, 0.1016, 0.0703, 0.0625, 0.0547, 0.0000]
y = [1.00000, 0.84123, 0.78871, 0.73722, 0.68717, 0.23151, 0.00332, -0.13641, -0.20581, -0.21090, -0.15662, -0.10150, -0.06434, -0.04775, -0.04192, -0.03717, 0.00000]


with open(filename, 'r') as file:
    lines = file.readlines()

# 解析数据
variables = lines[0].strip().split('\t')
data_lines = lines[1:]

x2 = []
y2 = []

for line in data_lines:
    line = line.strip().split('\t')
    x2.append(float(line[0]))
    y2.append(float(line[1]))

# 绘制图形
plt.plot(x2, y2, 'b-')
plt.scatter(x, y, color='black')
plt.grid(True)
plt.show()
